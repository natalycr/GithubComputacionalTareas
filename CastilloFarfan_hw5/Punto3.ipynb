# %%
% pylab inline
import numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
Datos=np.loadtxt('circulos.dat', dtype=float)
print type (Datos)
Datos
size(Datos)
# Out:
# <type 'numpy.ndarray'>
# 58020

# %%
x= Datos[:,0]
y= Datos[:,1]

# %%
scatter(x,y,s=1)
#figure.figsize(50)
size(y)
figsize(10,10)

# %%
from scipy.fftpack import fft, fftfreq
n=29010
fft_x = fft(y) / n # FFT Normalized
freq = fftfreq(n) # Recuperamos las frecuencias
plt.plot(freq, np.abs(fft_x))
print freq
# Out:
# [  0.00000000e+00   3.44708721e-05   6.89417442e-05 ...,  -1.03412616e-04
#   -6.89417442e-05  -3.44708721e-05]
