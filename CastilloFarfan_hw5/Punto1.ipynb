# %%
% pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
from scipy import fftpack
import cv2
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def Gaussian_func(x):
    print math.exp(x^2)
x=np.linspace(1,2000,2000)
x=int(float(x[:]))
print x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-652ef9f8a460> in <module>()
#       2     print exp^(x^2)
#       3 x=np.linspace(1,2000,2000)
# ----> 4 x=int(float(x[:]))
#       5 print x
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
Im1= pylab.imread("full_moon.jpg")
pylab.imshow(Im1, cmap=cm.Greys_r)
plt.title("Imagen  1 Original", fontsize=20)
pylab.gray()

# %%
img = pylab.imread('full_moon.jpg',0)

f = np.fft.fft2(img)#
print "size f=", size(f)
n=size(f)# numero de 
w= np.fft.fftfreq(n, 2)
print "n=", size(w)
print w[:], w[:]
#fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(f))#shift))


plt.subplot(131),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.subplot(133), plot(n, f)#cmap = 'gray')
#plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

plt.show()
img.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ddc1f334ef18> in <module>()
#      16 plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
#      17
# ---> 18 plt.subplot(133), plot(n, f)#cmap = 'gray')
#      19 #plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
#      20
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2830         ax.hold(hold)
#    2831     try:
# -> 2832         ret = ax.plot(*args, **kwargs)
#    2833         draw_if_interactive()
#    2834     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# ...

# %% [markdown]
# #### Pasa Altas

# %%
rows, cols, capas = img.shape
crow,ccol = rows , cols
print crow, ccol
f[0:crow, 0:ccol , :] = 0 #shift 
f_ishift = np.fft.ifftshift(f)#shift)
img_back = np.fft.ifft2(f)#_ishift)
img_back = np.abs(img_back)

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
#plt.subplot(132),plt.imshow(img_back, cmap = 'gray')

plt.subplot(122),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# 296 300

# %%
img = cv2.imread('full_moon.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
shape(kernel)
# Out:
# (5, 5)

# %% [markdown]
# ###### #imag_tran[enx/4:3*enx/4,eny/4:3*eny/4,:]=0 # donde [desde0enx:hasta w=0 en x, de w=0eny,a todas capas de la imagen (:) ]
# imag_tran[enx/4:3*enx/4,eny/4:3*eny/4,:]=0
# #print imag_tran
# final1=ifft2(imag_tran).real
# plt.imshow(final1)
# shape(Im1)
# #plt.hist(imag_tran, 256, range=(0.0,1.0))

# %%
Im2= pylab.imread("20_popc_cho009-1.tif",0)

pylab.imshow(Im2, cmap=cm.Greys_r)
plt.title("Imagen  2 Original", fontsize=20)

fft2 = np.fft.fft2(Im2) # grafica la transformada de  fouries  en 2D 
Im2.shape # Solo  tiene columnas y filas 
print "tama~no en x", size(fft2[0]),"tama~no en y", size(fft2[0])
#print "Columna 1", fft2[0],"Columna 2" , fft2[1]
w_2D=numpy.fft.rfftfreq(512)

#print size(w_2D[0:]),size(w_2D[1:]), size(w_2D[2:])
size(w_2D[1:])
half_fft2=((2.0)*(1.0/fft2(w_2D[1]))
#half=  w_2D[1]
###scatter(half_n, half_fft2)
# Out:
#   File "<ipython-input-61-0bf1d9b02391>", line 16
#     ###scatter(half_n, half_fft2)
#                                  ^
# SyntaxError: invalid syntax

# %%
#Im2.shape # Solo  tiene columnas y filas
colum, filas= Im2.shape
crow,ccol = rows , cols

fft2[0:crow+560,0:ccol+512]=0
#tran[colum+0:colum+560,filas+0:filas+512]=0
#f_ishift = np.fft.ifftshift(tran)
img_back = np.fft.ifft2(tran)#_ishift)
img_back=np.abs(img_back)

plt.subplot(121),plt.imshow(Im2),plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(img_back),plt.title('Con filtro')
plt.xticks([]), plt.yticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-f580d94926a8> in <module>()
#       6 #tran[colum+0:colum+560,filas+0:filas+512]=0
#       7 #f_ishift = np.fft.ifftshift(tran)
# ----> 8 img_back = np.fft.ifft2(tran)#_ishift)
#       9 img_back=np.abs(img_back)
#      10
#
# NameError: name 'tran' is not defined

# %%
kernel = np.ones((560,512),np.float32)/25
aplfil=Tran2*kernel
img_back = np.fft.ifft2(aplfil)#_ishift)
img_back=np.abs(img_back)

plt.subplot(121),plt.imshow(Im2),plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(img_back),plt.title('Con filtro')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
kernel = np.ones((5,5),np.float32)/25
nuevI = cv2.filter2D(Im2,-1,kernel)

plt.subplot(121),plt.imshow(Im2),plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(122),plt.imshow(nuevI),plt.title('Con filtro')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
Im3=pylab.imread("colesterol-1.tif")
pylab.imshow(Im3, cmap=cm.Greys_r)
plt.title("Imagen 3 Original", fontsize=20)

# %%
Im4=pylab.imread("ves_full_150_002-1.tif",0)
pylab.imshow(Im4, cmap=cm.Greys_r)
plt.title("Imagen 4 Original", fontsize=20)

# %%
f = np.fft.fft2(Im4)#
#fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(f))#shift))

plt.subplot(121),plt.imshow(Im4, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
Im4.shape
# Out:
# (576, 544)

# %%
rows, cols = Im4.shape
crow,ccol = rows , cols
f[crow +0:crow+576, ccol+100:ccol+544] = 0 #shift 
f_ishift = np.fft.ifftshift(f)#shift)
img_back = np.fft.ifft2(f)#_ishift)
img_back = np.abs(img_back)

plt.subplot(121),plt.imshow(Im4, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
#plt.subplot(132),plt.imshow(img_back, cmap = 'gray')

plt.subplot(122),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# transformada 2D
#n=2000 # nimeto de  puntps  que  quiero para fourier
fft2 = np.fft.fft2(Im1)
plt.imshow(fft2)
n=len(fft2) # nimeto de  puntps  que  quiero para fourier
w= np.fft.fftfreq(n)
p=[0,0,0,0]
append(w,p)
#print w
fft2_1=fft2[:]
print len(fft2[0]), len(fft2[1]), len(w), size(fft2_1)
#plt.plot(fft2)
#print fft2_1
