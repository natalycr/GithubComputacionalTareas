# %%
% pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
from scipy import fftpack
import cv2
from math import exp
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
def Gaussian_func(x):
    #a, mu,sigma = p
    return e**(-x**2)

# Gaussian FILTRO DE ALTAS
x= np.linspace(-50,50,200)
ecga=np.exp(-0.0005*x**2)
ecga= ecga/np.trapz(ecga)# normaliza ecga
pylab.subplot(121),plot(ecga)

#Kernel 2-D
kernel= ecga[:,np.newaxis]* ecga[np.newaxis, :]
print Im1.shape[:2], "Soy yo"
pylab.subplot(122),imshow(kernel)
# Out:
# (296, 300) Soy yo
# (<matplotlib.axes.AxesSubplot at 0xaef7b10>,
#  <matplotlib.image.AxesImage at 0xca9f9d0>)

# %%
# Gaussian FILTRO DE BAJAS
n=1
x2= np.linspace(-10,10,20)
ecga2=-np.exp(-0.005*x**2)+n
ecga2= ecga2/np.trapz(ecga2)# normaliza ecga
pylab.subplot(121),plot(ecga2)

#Kernel 2-D
kernel= ecga2[:,np.newaxis]* ecga2[np.newaxis, :]
print Im1.shape[:2], "Soy yo"
pylab.subplot(122),imshow(kernel)
# Out:
# (296, 300) Soy yo
# (<matplotlib.axes.AxesSubplot at 0x6c53390>,
#  <matplotlib.image.AxesImage at 0xccc5d90>)

# %%
#Kernel 2-D
kernel= ecga2[:,np.newaxis]* ecga2[np.newaxis, :]
print Im1.shape[:2], "Soy yo"
imshow(kernel)
# Out:
# (296, 300) Soy yo

# %%
x=np.linspace(-2,2,2000)
#gauss=np.zeros(2000)
#p0=[1,0,1]

hi=Gaussian_func(x)
len(hi)
scatter(x, hi)

# %%
Im1= pylab.imread("full_moon.jpg")
pylab.imshow(Im1, cmap=cm.Greys_r)
plt.title("Imagen  1 Original", fontsize=20)
print shape(Im1), "me lo tiro"

# Gaussian
x= np.linspace(-10,10,20)
ecga=np.exp(-0.05*x**2)
ecga= ecga/np.trapz(ecga)# normaliza ecga

#Kernel 2-D
kernel= ecga[:,np.newaxis]* ecga[np.newaxis, :]
print Im1.shape[:2], "Soy yo"

# la "transformada" del kernel 
ft_kernel=fftpack.fft2(kernel, shape=Im1.shape[:2], axes=(0, 1))

#convolve
ftt_imag=np.fft.fft2(Im1, axes=(0,1))
fft_imagcen=np.fft.fftshift(ftt_imag)
ftt_imag2=ft_kernel*ftt_imag
final=fft.ifft2(img2_ft, axes=(0, 1)).real
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-4b21d878e886> in <module>()
#      19 ftt_imag=np.fft.fft2(Im1, axes=(0,1))
#      20 fft_imagcen=np.fft.fftshift(ftt_imag)
# ---> 21 ftt_imag2=ft_kernel*ftt_imag
#      22 final=fft.ifft2(img2_ft, axes=(0, 1)).real
#
# ValueError: operands could not be broadcast together with shapes (296,300) (296,300,3)
# (296, 300, 3) me lo tiro
# (296, 300) Soy yo

# %%
fig =plt.figure(1,figsize=(9.5,9))#cambier rango 
plt.imshow(final)

plt.subplot(121),plt.imshow(Im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(final),plt.title('Filtro pasa bajas')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# No pudimos solucionar el problema de las differencias de tama~no. por lo que se implemento la libreria cv2
img = cv2.imread('full_moon.jpg')

kernel = np.ones((5,5),np.float32)/25
final = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(Im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(final),plt.title('Filtro pasa bajas')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
Im2= pylab.imread("20_popc_cho009-1.tif")
plt.subplot(121), pylab.imshow(Im2, cmap=cm.Greys_r)
plt.title("Imagen  1 Original", fontsize=20)
print shape(Im2)

# Gaussian
x= np.linspace(-10,10,20)
ecga=np.exp(-0.005*x**2)
ecga= ecga/np.trapz(ecga)# normaliza ecga

#Kernel 2-D
kernel= ecga[:,np.newaxis]* ecga[np.newaxis, :]
print Im2.shape[:2], "Soy yo"
plt.subplot(122),pylab.imshow(kernel)

# la "transformada" del kernel 
ft_kernel=fftpack.fft2(kernel, shape=Im2.shape[:2], axes=(0, 1))
#print  size(ft_kernel), "kernel"

#convolve
ftt_imag=np.fft.fft2(Im2, axes=(0,1))
fft_imagcen=np.fft.fftshift(ftt_imag)# centra

ftt_imag2=ft_kernel*ftt_imag
#ftt_imag2=ft_kernel*fft_imagcen # centrada

final=np.fft.ifft2(ftt_imag2, axes=(0, 1)).real
# Out:
# (560, 512)
# (560, 512) Soy yo

# %%
fig =plt.figure(1,figsize=(10,10))#cambier rango 


plt.subplot(121),plt.imshow(Im2, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(final, cmap=cm.Greys_r),plt.title('Filtro pasa bajas')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# FILTRO ALTAS
fig =plt.figure(1,figsize=(10,10))#cambier rango 

print shape(Im2)

#Kernel 2-D
kernel= ecga2[:,np.newaxis]* ecga2[np.newaxis, :]
print Im2.shape[:2], "Soy yo"

ft_kernel=fftpack.fft2(kernel, shape=Im2.shape[:2], axes=(0, 1))

ftt_imag2=ft_kernel*ftt_imag 
#ftt_imag2=ft_kernel*fft_imagcen # centrada

finaltas=np.fft.ifft2(ftt_imag2, axes=(0, 1)).real

plt.subplot(131),plt.imshow(Im2, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(finaltas, cmap=cm.Greys_r),plt.title('Filtro pasa ALTAS')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(final, cmap=cm.Greys_r),plt.title('Filtro pasa BAJAS')
plt.xticks([]), plt.yticks([])
# Out:
# (560, 512)
# (560, 512) Soy yo
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
Im3= pylab.imread("colesterol-1.tif")
pylab.imshow(Im3, cmap=cm.Greys_r)
plt.title("Imagen  1 Original", fontsize=20)
print shape(Im3)

# Gaussian
x= np.linspace(-10,10,20)
ecga=np.exp(-0.0005*x**2)
ecga= ecga/np.trapz(ecga)# normaliza ecga

#Kernel 2-D
kernel= ecga[:,np.newaxis]* ecga[np.newaxis, :]
print Im3.shape[:2], "Soy yo"

# la "transformada" del kernel 
ft_kernel=fftpack.fft2(kernel, shape=Im3.shape[:2], axes=(0, 1))

#convolve
ftt_imag=np.fft.fft2(Im3, axes=(0,1))
ftt_imag2=ft_kernel*ftt_imag
final3=np.fft.ifft2(ftt_imag2, axes=(0, 1)).real
# Out:
# (244, 357)
# (244, 357) Soy yo

# %%
fig =plt.figure(1,figsize=(10,10))#cambier rango 
#plt.imshow(final, cmap=cm.Greys_r)

plt.subplot(121),plt.imshow(Im3, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(final3, cmap=cm.Greys_r),plt.title('Filtro pasa bajas')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# FILTRO ALTAS
fig =plt.figure(1,figsize=(20,20))#cambier rango 

print shape(Im3)

#Kernel 2-D
kernel= ecga2[:,np.newaxis]* ecga2[np.newaxis, :]
print Im3.shape[:2], "Soy yo"

ft_kernel=fftpack.fft2(kernel, shape=Im3.shape[:2], axes=(0, 1))

ftt_imag3=ft_kernel*ftt_imag 
#ftt_imag2=ft_kernel*fft_imagcen # centrada

finaltas=np.fft.ifft2(ftt_imag3, axes=(0, 1)).real

plt.subplot(131),plt.imshow(Im3, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(finaltas, cmap=cm.Greys_r),plt.title('Filtro pasa ALTAS')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(final3, cmap=cm.Greys_r),plt.title('Filtro pasa BAJAS')
plt.xticks([]), plt.yticks([])
# Out:
# (244, 357)
# (244, 357) Soy yo
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
Im4= pylab.imread("ves_full_150_002-1.tif")
pylab.imshow(Im4, cmap=cm.Greys_r)
plt.title("Imagen  1 Original", fontsize=20)
print shape(Im4)

# Gaussian
x= np.linspace(-10,10,20)
ecga=np.exp(-0.0005*x**2)
ecga= ecga/np.trapz(ecga)# normaliza ecga

#Kernel 2-D
kernel= ecga[:,np.newaxis]* ecga[np.newaxis, :]
print Im4.shape[:2], "Soy yo"

# la "transformada" del kernel 
ft_kernel=fftpack.fft2(kernel, shape=Im4.shape[:2], axes=(0, 1))

#convolve
ftt_imag=np.fft.fft2(Im4, axes=(0,1))
ftt_imag2=ft_kernel*ftt_imag
final4=np.fft.ifft2(ftt_imag2, axes=(0, 1)).real
# Out:
# (576, 544)
# (576, 544) Soy yo

# %%
fig =plt.figure(1,figsize=(7,7))#cambier rango 
#plt.imshow(final)

plt.subplot(121),plt.imshow(Im4, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(final4, cmap=cm.Greys_r),plt.title('Filtro pasa bajas')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# FILTRO ALTAS
fig =plt.figure(1,figsize=(15,15))#cambier rango 

print shape(Im4)

#Kernel 2-D
kernel= ecga2[:,np.newaxis]* ecga2[np.newaxis, :]
print Im4.shape[:2], "Soy yo"

ft_kernel=fftpack.fft2(kernel, shape=Im4.shape[:2], axes=(0, 1))

ftt_imag4=ft_kernel*ftt_imag
#ftt_imag2=ft_kernel*fft_imagcen # centrada

finaltas=np.fft.ifft2(ftt_imag4, axes=(0, 1)).real

plt.subplot(131),plt.imshow(Im4, cmap=cm.Greys_r),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(finaltas, cmap=cm.Greys_r),plt.title('Filtro pasa ALTAS')
plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(final4, cmap=cm.Greys_r),plt.title('Filtro pasa BAJAS')
plt.xticks([]), plt.yticks([])
# Out:
# (576, 544)
# (576, 544) Soy yo
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))
